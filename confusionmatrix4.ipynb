# %%
# %cd /content/drive/MyDrive/Colab\ Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# !ls
# Out:
# 'ADA BOOSTING WITH FEATURE IMPORTANCE .ipynb'
# 'AI DRIVEN LAB.ipynb'
# 'Bankcsv .ipynb'
#  BDT_Practicall.ipynb
# 'BDT PRACTICAL WEEK 1,2,3.ipynb'
# 'BDT PRACTICAL WEEK 4 and also 5th week (hive) .ipynb'
# 'BUSSINESS PROFIT DATA USING  DECISION TREE .ipynb'
# 'Codes .ipynb'
#  confusionmatrix4.ipynb
# 'CONFUSION MATRIX FOR IRIS DATA SET .ipynb'
# 'CREDIT CARD DETECTION.ipynb'
# 'DATA ENGINEERING SKILL SESSION.ipynb'
# 'Decision tree without labelling.ipynb'
# 'FDE LABS FROM WEEK 1 TO WEEK 5.ipynb'
# 'FDE PROJECT .ipynb'
# 'IRIS USING RANDOM FOREST.ipynb'
# 'multiple regression.ipynb'
# 'OVERALL ENTROPHY.ipynb'
#  PROBLEMS.ipynb
# 'PythonPractice .ipynb'
# 'RAG CHATBOT TRY 1.ipynb'
# 'Randomforest .ipynb'
# 'Simple ANN.ipynb'
# 'simply ann .ipynb'
# 'SYNTHTIC DATA GENERATION.ipynb'
# 'TITANIC CLEANED Random Forest Classifier  .ipynb'
# 'TITATIC DATA SET USING RANDOM FOREST CLASSIFIER.ipynb'
#  TRANSFORMERS.ipynb
# 'TravelDataset .ipynb'
#  Untitled
#  Untitled0.ipynb
# 'Untitled (1)'
#  Untitled1.ipynb
# 'Untitled (2)'
#  Untitled2.ipynb
#  Untitled3.ipynb
#  Untitled4.ipynb
# 'Using ONE HOT .ipynb'
# 'VECTOR WEIGHTED PROBLEM.ipynb'

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/Colab Notebooks/.git/

# %%
# !git remote add origin https://github.com/jaishnav002-lgtm/IIT-Projects.git

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score, precision_score, recall_score, f1_score
import matplotlib.pyplot as plt

actual = np.random.binomial(1, 0.9, size=1000)
pred = np.random.binomial(1, 0.9, size=1000)
cm = confusion_matrix(actual, pred)

cm_display = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[False, True])
cm_display.plot()
plt.show()

accuracy = accuracy_score(actual, pred)
print("Accuracy:", accuracy)
presion = precision_score(actual, pred)
print("presion:",presion)
recall = recall_score(actual, pred)
print("recall:",recall)
f1 = f1_score(actual, pred)
print("f1:",f1)

score = accuracy_score(actual, pred)
print("the scoore is :",score)

cm = confusion_matrix(actual, pred)
tn,tp,fn,fp = cm.ravel()
print(f"tn : {tn},tp : {tp},fn : {fn},fp : {fp}")
misclass = (fn+fp)/(tn+tp+fn+fp)
print(f"missclassification rate : {misclass}")
fpr = fp/(tn+fp)
print(f"false positive rate : {fpr}")
prevalance = (fn+tp)/(tp+tn+fp+fn)
print(f"Prevalance : {prevalance}")
# Out:
# 'accuracy = accuracy_score(actual, pred)\nprint("Accuracy:", accuracy)\npresion = precision_score(actual, pred)\nprint("presion:",presion)\nrecall = recall_score(actual, pred)\nprint("recall:",recall)\nf1 = f1_score(actual, pred)\nprint("f1:",f1)\n\nscore = accuracy_score(actual, pred)\nprint("the scoore is :",score)\n\ncm = confusion_matrix(actual, pred)\ntn,tp,fn,fp = cm.ravel()\nprint(f"tn : {tn},tp : {tp},fn : {fn},fp : {fp}")\nmisclass = (fn+fp)/(tn+tp+fn+fp)\nprint(f"missclassification rate : {misclass}")\nfpr = fp/(tn+fp)\nprint(f"false positive rate : {fpr}")\nprevalance = (fn+tp)/(tp+tn+fp+fn)\nprint(f"Prevalance : {prevalance}")'
